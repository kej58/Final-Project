# %% [markdown]
# # Best neighborhood in Pittsburgh

# %% [markdown]
# ## Team Square
# [Maxwell Quinn](msq4@pitt.edu)|
# [Keqing Jiang](kej58@pitt.edu)|
# [Jacob Gudich](jjg125@pitt.edu)

# %% [markdown]
# ![typing](https://media.giphy.com/media/PiQejEf31116URju4V/giphy.gif)

# %% [markdown]
# ### Introduction
#
# Using data from the WPRDC, the three dataset we considered are:
#
# * **Incident Rate** (_Police Incident Blotter_)
#     * The reason we choose the police incident data is because safety is always a primary consideration in choosing a neighborhood and the security of that neighborhood can be seen by the different crime incidents that are reported in different neighborhoods.
# ---
# * **Facilities** (_City of Pittsburgh Facilities_)
#     * Facilities are also an important consideration in choosing a neighborhood, and if a neighborhood has more facilities then that means the neighborhood has more access to different resources, which will make people’s lives more convenient.
# ---
# * **Public School**(_Pittsburgh Public School Location_)
#     * Public school is an important consideration because living in a neighborhood that is close to the  school will make life more convenient for both parents and children. Living close to a school can also reflect on the safeness of that neighborhood and the school yard can also be open for public use.

# %% [markdown]
# ### The Metric
# 1. _**[Police Incident Blotter(30 Day)](https://data.wprdc.org/dataset/police-incident-blotter)**_
#     * The 30-Day Police Blotter contains the most recent initial crime incident data, updated on a nightly basis. All data is reported at the block/intersection level, with the exception of sex crimes, which are reported at the police zone level.
#     * From this data we want to find out the neighborhood with the least reported incident in the past 30 days.So in this dataset we first look for which crime reported the most, then use the information to find out the top three reported crimes and see in which neighborhood they were reported and compare it with the information from the previous data(the reported crime).
# ---
# 2. _**[City of Pittsburgh Facilities](https://data.wprdc.org/dataset/city-of-pittsburgh-facilities)**_
#     * This dataset contains the information of different facilities in Pittsburgh, and the City Facility data pulled from the Operations Management System for the Department of Public Works.
#     * From this data we want to find out the neighborhood with the most facilities.
# ---
# 3. _**[Pittsburgh Public School Locations](https://data.wprdc.org/dataset/pittsburgh-public-school-locations)**_
#     * This dataset has information about all the public schools around Pittsburgh, including name of the public school, location in Pittsburgh with latitude, longitude and zip code and address.
#     *

# %% [markdown]
# ### The best neighborhood in Pittsburgh
# * **Police Incident Blotter (30 Day)**: In order to find out what is the best neighborhood in Pittsburgh, we need to find out which neighborhood has the least reported crime/incident. So in this dataset we first look for which crime reported the most, then use the information to find out the top three reported crimes and see in which neighborhood they were reported and compare it with the information from the previous data(the reported crime). Lastly,  find out which neighborhood have the least reported crimes, which leads to the following conclusion:
#     * Neighborhood in Pittsburgh that have the <font color='green'>least </font>indecent: <font color='red'>***Regent Square***</font>, with only *two* incidents reported in the past 30 days.
#
#
# * **City of Pittsburgh Facilities**:
#
# * **Pittsburgh Public School Location**:
#
# * Overall, the best neighborhood in Pittsburgh is ** ** because

# %% [markdown]
# ### Conclusion:
# *
# *
# *

# %% [markdown]
# ### Data

# %% [markdown]
# #### **Incident rate**
# ![gif](https://media.giphy.com/media/Bc3SkXz1M9mjS/giphy.gif)

# %%
#import pandas
import pandas as pd
#import matplotlib for graphing
import matplotlib.pyplot as plt

# %%
#We first import the data from a csv file and display the first 5 rows
blotter_data = pd.read_csv('BlotterData.csv')
blotter_data.head()
# Out:
#           PK       CCR  HIERARCHY         INCIDENTTIME  \
# 0  236465923  20186838          6  2020-10-06T13:09:00
# 1  235551833  20182673         10  2020-09-30T02:19:00
# 2  235556220  20182674          0  2020-09-30T02:15:00
# 3  235667331  20183062          0  2020-09-30T16:40:00
# 4  235698060  20183325         99  2020-09-30T23:15:00
#
#                                 INCIDENTLOCATION CLEAREDFLAG  \
# 0      100 Block Hazlett St Pittsburgh, PA 15214           N
# 1        2300 Block Jane St Pittsburgh, PA 15203           Y
# 2    700 Block N Dallas Ave Pittsburgh, PA 15208           Y
# 3  Becks Run Rd & Wagner St Pittsburgh, PA 15210           Y
# 4         100 Block Pius St Pittsburgh, PA 15203           Y
#
#   INCIDENTNEIGHBORHOOD INCIDENTZONE     INCIDENTHIERARCHYDESC  \
# 0    Northview Heights            1                     THEFT
# 1     South Side Flats            3            SIMPLE ASSAULT
# 2        Homewood West            5                        99
# ...

# %%
#count incident that happened in each location and list it in numerical order
blotter_data['INCIDENTLOCATION'].value_counts().sort_values(ascending=True)
# Out:
# 600 Block N Atlantic Ave Pittsburgh, PA 15224        1
# Woods Run Ave & Brighton Rd Pittsburgh, PA 15212     1
# 4200 Block Windsor St Pittsburgh, PA 15217           1
# 900 Block N Murtland St Pittsburgh, PA 15208         1
# 1800 Block Winhurst St Pittsburgh, PA 15212          1
#                                                     ..
# 400 Block N Highland Ave Pittsburgh, PA 15206       12
# 1400 Block Washington Blvd Pittsburgh, PA 15206     12
# 1200 Block Western Ave Pittsburgh, PA 15233         17
# 1700 Block Arlington Ave Pittsburgh, PA 15210       21
# 600 Block 1st Ave Pittsburgh, PA 15219              21
# Name: INCIDENTLOCATION, Length: 2174, dtype: int64

# %%
#Use the matplotlib for graphing
#Graph it as a pie chart to see which incident reported the most
plt.rcParams['figure.figsize']=(20,20)
plt.title('Incident Reported', fontweight=30,fontsize=20)
plt.style.use("seaborn")
#Find out the most reported crime
rate=blotter_data.INCIDENTHIERARCHYDESC.value_counts()
#plot it as a bar graph
rate.iloc[:10].sort_values().plot.pie()
plt.xticks(rotation=90)
plt.show()

# %%
#report the first 10 neigborhood that report 99
#99 is the emergency service response code
report = blotter_data[blotter_data.INCIDENTHIERARCHYDESC.str.contains('99')];
report.INCIDENTNEIGHBORHOOD.value_counts()
report.iloc[:10]
# Out:
#            PK       CCR  HIERARCHY         INCIDENTTIME  \
# 2   235556220  20182674          0  2020-09-30T02:15:00
# 3   235667331  20183062          0  2020-09-30T16:40:00
# 8   237050509  20192770          0  2020-10-15T10:13:00
# 13  237070573  20192854          0  2020-10-15T12:00:00
# 17  236496107  20188815          0  2020-10-09T10:15:00
# 18  238219511  20202344          0  2020-10-29T13:05:00
# 19  236726821  20190722          0  2020-10-12T09:00:00
# 22  236806908  20191043          0  2020-10-12T16:15:00
# 25  236815642  20190890          0  2020-10-12T16:20:00
# 35  235818207  20183843          0  2020-10-01T17:43:00
#
#                                   INCIDENTLOCATION CLEAREDFLAG  \
# 2      700 Block N Dallas Ave Pittsburgh, PA 15208           Y
# 3    Becks Run Rd & Wagner St Pittsburgh, PA 15210           Y
# 8         6200 Block Broad St Pittsburgh, PA 15206           N
# 13     2200 Block Bedford Ave Pittsburgh, PA 15219           N
# ...

# %%
#report the first 10 neigborhood that report theft
report = blotter_data[blotter_data.INCIDENTHIERARCHYDESC.str.contains('THEFT')];
report.INCIDENTNEIGHBORHOOD.value_counts()
report.iloc[:10]
# Out:
#            PK       CCR  HIERARCHY         INCIDENTTIME  \
# 0   236465923  20186838          6  2020-10-06T13:09:00
# 10  237060289  20192796          6  2020-10-15T10:53:00
# 15  237083763  20192910          6  2020-10-15T10:10:00
# 27  236817779  20191226          6  2020-10-13T01:30:00
# 30  236292513  20187410          6  2020-10-07T09:39:00
# 40  237219691  20194392          6  2020-10-17T13:57:00
# 42  237228056  20194520         11  2020-10-17T18:19:00
# 47  238286322  20202893          6  2020-10-30T09:30:00
# 48  238292620  20202876          6  2020-10-30T10:20:00
# 56  237563734  20197047          6  2020-10-17T13:45:00
#
#                                  INCIDENTLOCATION CLEAREDFLAG  \
# 0       100 Block Hazlett St Pittsburgh, PA 15214           N
# 10                    PPG Pl Pittsburgh, PA 15222           N
# 15     2000 Block Wharton St Pittsburgh, PA 15203           N
# 27     2900 Block Mullins St Pittsburgh, PA 15212           N
# ...

# %%
#report the first 10 neigborhood that report simple assault
report = blotter_data[blotter_data.INCIDENTHIERARCHYDESC.str.contains('HIT AND RUN')];
report.INCIDENTNEIGHBORHOOD.value_counts()
report.iloc[:10]
# Out:
#             PK       CCR  HIERARCHY         INCIDENTTIME  \
# 7    237048867  20192753         27  2020-10-15T09:20:00
# 12   237066812  20192794         27  2020-10-15T10:50:00
# 26   236815738  20191147         27  2020-10-12T22:51:00
# 44   237101732  20191695         27  2020-10-14T18:52:00
# 57   237566758  20197062         27  2020-10-21T10:15:00
# 65   237101529  20193012         27  2020-10-15T15:30:00
# 91   237281430  20193905         27  2020-10-16T19:35:00
# 115  236959578  20192079         27  2020-10-13T16:30:00
# 122  235924893  20184530         27  2020-10-02T15:30:00
# 123  235927050  20184588         27  2020-10-02T19:00:00
#
#                                       INCIDENTLOCATION CLEAREDFLAG  \
# 7    Fort Duquesne Blvd & Fort Duquesne Blvd Ramp P...           N
# 12   Ohio River Blvd & Mckees Rocks Brg Pittsburgh,...           Y
# 26            300 Block Wabana St Pittsburgh, PA 15214           Y
# ...

# %%
#count the first 20 neighborhood with the least crime reported
less_crime=blotter_data.groupby('INCIDENTNEIGHBORHOOD').size().sort_values(ascending=True)
less_crime.head(20)
# Out:
# INCIDENTNEIGHBORHOOD
# Regent Square         2
# Mt. Oliver Boro       2
# Oakwood               2
# Outside County        2
# St. Clair             2
# Ridgemont             3
# Swisshelm Park        4
# East Carnegie         4
# Mount Oliver          4
# Hays                  4
# Allegheny West        6
# Chartiers City        6
# Glen Hazel            6
# Arlington Heights     7
# Esplen                8
# Outside State         8
# Polish Hill           9
# Spring Garden         9
# West End             10
# Stanton Heights      12
# dtype: int64

# %%
#plot the region with the least incident reported
data = less_crime.head(20).plot(figsize=(20,10),kind='barh',title="Neighborhood with least incident")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### **Facilities**
# ![swing](https://media.giphy.com/media/SbwGrFfajN4OI/giphy.gif)

# %%
##import the data from a csv file and display the first 5 rows
facil = pd.read_csv("facil.csv")
facil.head()
# Out:
#            id  parcel_id inactive  \
# 0   650726265  120-J-300        f
# 1   783044037    2-H-284        f
# 2  1997158435   23-R-157        f
# 3   204824684   10-F-198        f
# 4   472140955  013-K-314        f
#
#                                                 name rentable     type  \
# 0                          57th Street Park Building        f  Storage
# 1                    Albert Turk Graham Park Shelter        f  Shelter
# 2  Allegheny Northside Senior Center and Hazlett ...        t   Senior
# 3                            Ammon Recreation Center        f     Pool
# 4                    Arlington Field Lights Building        f  Utility
#
#                  primary_user  address_number          street      zip  ...  \
# 0  Department of Public Works             NaN         57TH ST      NaN  ...
# 1  Department of Public Works            39.0         VINE ST      NaN  ...
# 2                   CitiParks             5.0  ALLEGHENY SQ E  15212.0  ...
# ...

# %%
##use the length function to get the total amount of data points

len(facil)
# Out:
# 407

# %%
##display the first 5 rows again, but this time have the first collumn display the neighborhood name
facil2 = pd.read_csv("facil.csv",index_col="neighborhood")
facil2.head()
# Out:
#                              id  parcel_id inactive  \
# neighborhood
# Upper Lawrenceville   650726265  120-J-300        f
# Crawford-Roberts      783044037    2-H-284        f
# Allegheny Center     1997158435   23-R-157        f
# Bedford Dwellings     204824684   10-F-198        f
# South Side Slopes     472140955  013-K-314        f
#
#                                                                   name  \
# neighborhood
# Upper Lawrenceville                          57th Street Park Building
# Crawford-Roberts                       Albert Turk Graham Park Shelter
# Allegheny Center     Allegheny Northside Senior Center and Hazlett ...
# Bedford Dwellings                              Ammon Recreation Center
# South Side Slopes                      Arlington Field Lights Building
#
#                     rentable     type                primary_user  \
# neighborhood
# Upper Lawrenceville        f  Storage  Department of Public Works
# ...

# %%
##count each type of facility in ascending order
##we can see that shelters are the most dominant at 61

facil['type'].value_counts().sort_values(ascending=True)
# Out:
# Vacant            1
# OFFICE            2
# TRAINING          2
# Training          2
# SERVICE           3
# Community         3
# Recycling         3
# Cabin             4
# Pool Closed       4
# STORAGE           6
# Rec Center        6
# Pool/Rec          6
# POLICE            7
# Police            8
# Salt Dome         8
# Medic Station    10
# Senior           16
# Restrooms        17
# Activity         18
# Utility          19
# Office           23
# Storage          24
# Pool             25
# Service          26
# Firehouse        28
# Concession       32
# Dugout           42
# Shelter          61
# Name: type, dtype: int64

# %%
##create a pie chart to show the least/most facilities another way
##this pie chart is very simple to read, and we can clearly see that shelter is first, dugout is second, and consession is third

plt.rcParams['figure.figsize']=(25,17)
plt.title('Facility', fontweight=20,fontsize=20)
plt.style.use("seaborn")
pie = facil.type.value_counts()
pie.iloc[:30].sort_values().plot.pie()
plt.xticks(rotation=90)
plt.show()

# %%
##list the number of facilities from each neighborhood
##there are several neighborhoods with only 1 facility, but Highland Park contains the most
##we also get the total number of neighborhoods at the very bottom of the output (75)

hood_list = facil.groupby('neighborhood').size().sort_values(ascending=True)
hood_list
# Out:
# neighborhood
# Stanton Heights         1
# Glen Hazel              1
# East Allegheny          1
# Point Breeze North      1
# Crafton Heights         1
#                        ..
# Strip District         15
# Brookline              19
# Perry North            20
# Squirrel Hill South    29
# Highland Park          30
# Length: 75, dtype: int64

# %%
##create a query mask to display the first 5 neighborhoods that include shelters

query_mask = facil2['type'] == 'Shelter'

shelter = facil2[query_mask]
shelter.head()
# Out:
#                           id parcel_id inactive  \
# neighborhood
# Crawford-Roberts   783044037   2-H-284        f
# Banksville         635191366  17-R-120        f
# Bon Air            239855066  34-M-131        f
# Brighton Heights  1944072896  115-E-40        f
# Brookline          372308265    96-G-1        f
#
#                                              name rentable     type  \
# neighborhood
# Crawford-Roberts  Albert Turk Graham Park Shelter        f  Shelter
# Banksville                 Banksville Park Gazebo        f  Shelter
# Bon Air                           Bon Air Shelter        f  Shelter
# Brighton Heights    Brighton Heights Park Shelter        t  Shelter
# Brookline                 Brookline Lower Shelter        f  Shelter
#
#                                 primary_user  address_number  \
# neighborhood
# Crawford-Roberts  Department of Public Works            39.0
# Banksville        Department of Public Works             NaN
# ...

# %%
##create a query mask to display all of the rec centers, there should be 6

query_mask = facil2['type'] == 'Rec Center'

rec = facil2[query_mask]
rec
# Out:
#                                   id          parcel_id inactive  \
# neighborhood
# Brookline                 2070467175             96-G-1        f
# Lincoln-Lemington-Belmar      269075  173-L-039,040,163        f
# Troy Hill                 2006688044           24-G-270        f
# Central Northside          257471611           23-E-106        f
# Lincoln-Lemington-Belmar   477492276          124-H-116        f
# Upper Hill                1799791498           26-P-250        f
#
#                                                          name rentable  \
# neighborhood
# Brookline                         Brookline Recreation Center        t
# Lincoln-Lemington-Belmar           Chadwick Recreation Center        f
# Troy Hill                            Cowley Recreation Center        f
# Central Northside                 Jefferson Recreation Center        f
# Lincoln-Lemington-Belmar            Paulson Recreation Center        t
# ...

# %%
##since Highland Park contains the most facilities, lets see everything it includes

query_mask = facil['neighborhood'] == 'Highland Park'
Highland = facil[query_mask]
Highland

##pay attention to this collumn:                        (HERE)
# Out:
#              id   parcel_id inactive  \
# 9     436558867         NaN        f
# 10   1534014655    122-L-50        f
# 11    287640271    122-L-50        f
# 138   317858517  82-H-1-0-2        f
# 139   975171008  82-H-1-0-2        f
# 140  1232356456  82-H-1-0-2        f
# 141   649027918  82-H-1-0-2        f
# 142    63545891  82-H-1-0-2        f
# 143   130294472  82-H-1-0-2        f
# 144   202870739  82-H-1-0-2        f
# 145  1523072102  82-H-1-0-2        f
# 146  1117865113  82-H-1-0-2        f
# 147   675071669  82-H-1-0-2        f
# 148  2131696007  82-H-1-0-2        f
# 149  1582481712  82-H-1-0-2        f
# 150   712815606    82-H-102        f
# 151   326734985  82-H-1-0-2        f
# 152  1299757694  82-H-1-0-2        f
# 243  1256368314  82-H-1-0-2        f
# 244   377970813  82-H-1-0-2        f
# 269  1513172118  82-H-1-0-2        f
# 270  1211771847  82-H-1-0-2        f
# 274  1983926964  82-H-1-0-2        f
# 275   483957301  82-H-1-0-2        f
# ...

# %%
##count the 10 neighborhoods that include the most facilities

most = facil.groupby('neighborhood').size().sort_values(ascending=False)
most.head(10)
# Out:
# neighborhood
# Highland Park          30
# Squirrel Hill South    29
# Perry North            20
# Brookline              19
# Strip District         15
# Hazelwood              14
# Brighton Heights       14
# Carrick                12
# Elliott                11
# South Side Slopes      11
# dtype: int64

# %%
##plot these 10 facility-heavy neighborhoods with a bar graph

data = most.head(10).plot(figsize=(20,10),kind='barh',title="NEIGHBORHOODS WITH THE MOST FACILITIES")
plt.show()

# %% [markdown]
# ---
# #### **Public School**
# ![book](https://media.giphy.com/media/fhAwk4DnqNgw8/giphy.gif)

# %% [markdown]
# ![finish](https://media.giphy.com/media/3o6Mbnll2gudglC3HG/giphy.gif)
