# %%
#import pandas
import pandas as pd
#import matplotlib for graphing
import matplotlib.pyplot as plt

#import data from csv file and display first 5 lines
school_locations = pd.read_csv("SchoolLocations.csv")
school_locations.head()
# Out:
#    sourcedid                        name            address        city state  \
# 0       9861  Allderdice Early Headstart  2409 Shady Avenue  Pittsburgh    PA
# 1        301      Allderdice High School     2409 SHADY AVE  PITTSBURGH    PA
# 2        204               Allegheny 6-8        810 ARCH ST  PITTSBURGH    PA
# 3       9863   Allegheny Early Childhood    810 ARCH STREET  Pittsburgh    PA
# 4        102               Allegheny K-5        810 ARCH ST  PITTSBURGH    PA
#
#      zip   latitude  longitude
# 0  15217  40.429415 -79.919132
# 1  15217  40.429416 -79.919370
# 2  15212  40.453231 -80.008655
# 3  15212  40.453266 -80.008600
# 4  15212  40.453181 -80.008895

# %%
#count schools in each zip code
school_locations['zip'].value_counts().sort_values(ascending=True)

#Use the matplotlib for graphing
plt.rcParams['figure.figsize']=(20,12)
plt.title('Schools by zipcode', fontweight=20,fontsize=20)
plt.style.use("seaborn")
#Find out the number of schools in each zip code
zip=school_locations.zip.value_counts()
#graph it
zip.iloc[:10].sort_values().plot.pie()
plt.xticks(rotation=90)
plt.show()

# %%
#towns in zipcode
print("Towns in zip code 15201 are Central Lawrenceville, Garfield, Lower lawrenceville, Morningside, Polish Hill, Stanton Heights, Strip District, Upper Lawrenceville.")
print("Towns in zip code 15203 are Allentown, Arlington, Arlington Heights, Mount Washington, South Shore, Southside Flats, Southside Slopes.")
print("Towns in zip code 15204 are Chartiers, Crafton Heoghts, Esplen, Fairywood, Sheraden, Windgap.")
print("Towns in zip code 15205 are Crafton Heights, East Cranegie, Elliot, fairywood, Oakwood, West End, Westwood, Windgap.")
print("Towns in zip code 15206 are Bloomfield, East Liberty, Friendship, Garfield, Highland Park, Homewood North, Homewood West, Larimer, Lincoln-Lemington-Belmar, Morningside.")
print("Towns in zip code 15207 are West Homestead, Central Oakland, Glen Hazel, Greenfield, Hays, Hazelwood, Lincoln Place, New Homestead, South Oakland, Squirrel Hill North.")
print("Towns in zp code 15208 are East Hills, Homewood North, Homewood South, Homewood West, Larimer, Point Breeze, Point Breeze North, Squirrel Hill North.")
print("Towns in zip code 15210 are Allentown, Arlington, Arlington Heights, Beechville, Beltzhoover, Bon Air, Brookline, Carrick, Hays, Knoxville.")
print("Towns in zip code 15211 are Allentown, Beechville, Beltzhoover, Duquesne Heights, Elliot, Mount Washington, South Shore, West End.")
print("Towns in zip code 15212 are Allegheny Center, Allegheny West, Brighton Heights, California-Kirkbride, Central Northside, Chateau, East Allegheny, Fineview, Herrs Island, Manchester.")
print("Towns in zip code 15213 are Bedford Dwellings, Bloomfield, Bluff, Central Oakland, Lower Lawrenceville, North Oakland, Polish Hill, Shadyside, South Oakland, Squirrel Hill North.")
print("Towns in zip code 15214 are Brighton Heights, California-Kirkbride, Central Northside, Fineview, Marshall-Shadeland, Northview Heights, Perry North, Perry South, Spring Hill City View, Summer Hill.")
print("Towns in zip code 15216 are Banksville, Beechville, Brookline.")
print("Towns in zip code 15217 are Glen Hazel, Greenfield, Hazelwood, Point Breeze, Regent Square, Squirrel Hill North, Squirrel Hill South, Swisshelm Park.")
print("Towns in zip code 15218 are Bedford Dwellings, Bluff, Crawford Roberts Hill, Downtown Pittsburgh, Elliot, Hazelwood, Middle Hill, Mount Washington, North Oakland, Polish Hill.")
print("Towns in zip code 15220 are Banksville, Beechville, Crafton Heoghts, Duquesne Heights, Elliot, Esplen, Mount Washington, Oakwood, Sheraden, West End.")
print("Towns in zip code 15221 are East Hill, Homewood North, Homewood West, Point Breeze, Point Breeze North, Regent Square, Squirrel Hill South.")
print("Towns in zip code 15222 are Crawford Roberts Hill, Downtown Pittsburgh, Polish Hill, Strip District.")
print("Towns in zip code 15224 are Bloomfield, Central Lawrenceville, East Liberty, Garfield, Lower Lawrenceville, Morningside, North Oakland, Polish Hill, Shadyside, Stanton Heights.")
print("Towns in zip code 15226 are Beechville, Bon Air, Brookline, Carrick, Overbrook.")
print("Towns in zip code 15232 are Bloomfield, East Liberty,Friendship, Point Breeze, Shadyside, Squirrel Hill North.")
print("Towns in zip code 15233 are Allegheny West, Brighton Heights, Brunots Island, California-Kirkbride, Central Northside, Chateau, Manchester, Marshell Shadeland.")
# Out:
# Towns in zip code 15201 are Central Lawrenceville, Garfield, Lower lawrenceville, Morningside, Polish Hill, Stanton Heights, Strip District, Upper Lawrenceville.
# Towns in zip code 15203 are Allentown, Arlington, Arlington Heights, Mount Washington, South Shore, Southside Flats, Southside Slopes.
# Towns in zip code 15204 are Chartiers, Crafton Heoghts, Esplen, Fairywood, Sheraden, Windgap.
# Towns in zip code 15205 are Crafton Heights, East Cranegie, Elliot, fairywood, Oakwood, West End, Westwood, Windgap.
# Towns in zip code 15206 are Bloomfield, East Liberty, Friendship, Garfield, Highland Park, Homewood North, Homewood West, Larimer, Lincoln-Lemington-Belmar, Morningside.
# Towns in zip code 15207 are West Homestead, Central Oakland, Glen Hazel, Greenfield, Hays, Hazelwood, Lincoln Place, New Homestead, South Oakland, Squirrel Hill North.
# ...
